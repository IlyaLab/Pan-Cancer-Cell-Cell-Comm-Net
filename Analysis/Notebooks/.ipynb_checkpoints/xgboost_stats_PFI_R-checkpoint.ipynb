# %%
library(dplyr)
library(stringr)
library(readr)
library(tidyr)
library(caret)
library(ggplot2)
library(igraph)
library(ggraph)

# %%
# this is pulled from the BigQuery weights table
pfidat <- read_csv('../Data/manuscript-studies-pfi-test-DWE-weights.csv.gz')
# Out:
# Parsed with column specification:
# cols(
#   Study = col_character(),
#   EdgeID = col_double(),
#   LCell = col_character(),
#   Ligand = col_character(),
#   Receptor = col_character(),
#   RCell = col_character(),
#   S1 = col_double(),
#   med_diff = col_double(),
#   AliquotBarcode = col_character(),
#   PatientBarcode = col_character(),
#   EdgeWt = col_double(),
#   Stage = col_double(),
#   PFI = col_double()
# )

# %%
studies <- pfidat %>% dplyr::select(PatientBarcode, Study) %>% unique() %>% group_by(Study) %>% count()        # now required with changes to dplyr::count()

studies  # coad, esca, lusc, paad, read, skcm, stad
         # 1     2     3     4     5     6     7
# Out:
#   Study n
# 1 COAD  281
# 2 ESCA  170
# 3 LUSC  483
# 4 PAAD  151
# 5 READ   88
# 6 SKCM  102
# 7 STAD  389

# %%
# selecting one tissue type
selectedStudy <- studies$Study[7]
#
dat <- pfidat %>% dplyr::filter(Study == selectedStudy)
head(dat)
# Out:
#   Study EdgeID LCell         Ligand Receptor RCell            S1
# 1 STAD  664468 Monocytes     HGF    CD44     Melanocytes       0.1363150
# 2 STAD  276510 CLP           TFPI   SDC4     Sebocytes         0.1449398
# 3 STAD  271371 CLP           TFPI   SDC4     Epithelial cells  0.1391407
# 4 STAD  665014 Monocytes     CD55   EMR2     Monocytes         0.1392053
# 5 STAD  929738 Preadipocytes HSPG2  ITGA2    NKT              -0.1337764
# 6 STAD  664468 Monocytes     HGF    CD44     Melanocytes       0.1363150
#   med_diff    AliquotBarcode               PatientBarcode EdgeWt      Stage PFI
# 1  0.05449398 TCGA-VQ-A8PB-01A-11R-A39E-31 TCGA-VQ-A8PB   0.009823645 1     2
# 2  0.06148362 TCGA-BR-6453-01A-11R-1802-13 TCGA-BR-6453   0.045422381 1     2
# 3  0.06099753 TCGA-D7-A4YY-01A-11R-A251-31 TCGA-D7-A4YY   0.130246310 2     2
# 4  0.06950839 TCGA-VQ-AA69-01A-11R-A414-31 TCGA-VQ-AA69   0.015434520 2     2
# 5 -0.05932083 TCGA-RD-A8MW-01A-11R-A36D-31 TCGA-RD-A8MW   0.053836902 2     1
# 6  0.05449398 TCGA-MX-A663-01A-11R-A31P-31 TCGA-MX-A663   0.041031206 1     1

# %%
# counting samples

dat %>% dplyr::select(PatientBarcode, PFI) %>% unique() %>% group_by(PFI) %>% count()        # now required with changes to dplyr::count()
# Out:
#   PFI n
# 1  1  155
# 2  2  231
# 3 NA    3

# %%
length(unique(dat$EdgeID))
# Out:
# [1] 142

# %%
# making a matrix
dat2 <- dat %>% dplyr::select(PatientBarcode, EdgeID, EdgeWt) %>% group_by(PatientBarcode, EdgeID) %>% summarise(EdgeWt = mean(EdgeWt))
datmat <- pivot_wider(data = dat2, names_from = EdgeID, values_from = EdgeWt)
dim(datmat)
datmat[1:5,1:5]
# Out:
# [1] 389 143
#   PatientBarcode 58549      60750      63900      65156
# 1 TCGA-3M-AB46   0.02388772 0.05910395 0.02482554 0.03184748
# 2 TCGA-3M-AB47   0.25039088 0.20664852 0.49803594 0.36584917
# 3 TCGA-B7-5816   0.11720661 0.11783020 0.11974198 0.09782647
# 4 TCGA-B7-5818   0.09760146 0.13189802 0.07775963 0.12866040
# 5 TCGA-B7-A5TI   0.03672418 0.23499544 0.06279052 0.04687602

# %%
# to pull out the phenotype
labels <- sapply(datmat$PatientBarcode, function(a) (dat %>% dplyr::filter(PatientBarcode == a) %>% dplyr::select(PFI) %>% pull())[1])
# and match the datmat partient barcode order
labels <- labels[datmat$PatientBarcode]
labels <- sapply(labels, function(a) paste0('pfi_',a))

# %%
plotdat <- data.frame(Pheno=labels, Edge1=as.numeric(datmat[,5] %>% pull()))
head(plotdat)
qplot(data=plotdat, x=Pheno, y=Edge1, geom='boxplot', fill=as.factor(Pheno))
median(as.numeric(plotdat$Edge1[plotdat$Pheno == 1]), na.rm = T)  - median(as.numeric(plotdat$Edge1[plotdat$Pheno == 2]), na.rm = T)
# Out:
#              Pheno Edge1
# TCGA-3M-AB46 pfi_2 0.031847481
# TCGA-3M-AB47 pfi_2 0.365849174
# TCGA-B7-5816 pfi_2 0.097826473
# TCGA-B7-5818 pfi_2 0.128660405
# TCGA-B7-A5TI pfi_2 0.046876017
# TCGA-B7-A5TJ pfi_2 0.003793484
# [1] NA
# plot without title

# %%
# data prep #
x <- as.data.frame(datmat[,-1])     # 
x$Phenotype <- labels             # probably don't need this since it goes to factor
x <- x[x$Phenotype != 'pfi_NA', ] # remove NAs
colnames(x) <- c(sapply(colnames(x)[1:(ncol(x)-1)], function(a) paste0('edge_',a)), 'Phenotype')
x$Phenotype <- as.factor(x$Phenotype)
x[is.na(x)] <- 0

# %%
x[1:5,1:5]
dim(x)
# Out:
#   edge_58549 edge_60750 edge_63900 edge_65156 edge_85934
# 1 0.02388772 0.05910395 0.02482554 0.03184748 0.08627365
# 2 0.25039088 0.20664852 0.49803594 0.36584917 0.32092179
# 3 0.11720661 0.11783020 0.11974198 0.09782647 0.16217745
# 4 0.09760146 0.13189802 0.07775963 0.12866040 0.03623990
# 5 0.03672418 0.23499544 0.06279052 0.04687602 0.05021175
# [1] 386 143

# %%
# modeling the within data assocations

library(xgboost)

xmat <- as.matrix(x[,-ncol(x)])
ylab <- as.numeric(x$Phenotype)-1

dtrain <- xgboost::xgb.DMatrix(xmat, label=ylab)

param <- list(max_depth = 2, eta = 0.2, nthread = 2,
                objective = "binary:logistic", eval_metric = "auc")

mod <- xgboost::xgboost(data=dtrain, params = param, nrounds=100, early_stopping_rounds = 2)

pred <- predict(mod, xmat)

restab <- table(pred > 0.5, ylab)

head(xgboost::xgb.importance(model = mod), n=10)

restab
acc <- (restab[1,1]+restab[2,2]) / sum(restab)
acc
# Out:
# Attaching package: ‘xgboost’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     slice
# [1]	train-auc:0.726170
# Will train until train_auc hasn't improved in 2 rounds.
#
# [2]	train-auc:0.783117
# [3]	train-auc:0.811884
# [4]	train-auc:0.833515
# [5]	train-auc:0.844254
# [6]	train-auc:0.851320
# [7]	train-auc:0.859656
# [8]	train-auc:0.864097
# [9]	train-auc:0.870186
# [10]	train-auc:0.875157
# [11]	train-auc:0.882488
# [12]	train-auc:0.889178
# [13]	train-auc:0.895908
# [14]	train-auc:0.903701
# [15]	train-auc:0.905404
# [16]	train-auc:0.909398
# [17]	train-auc:0.911297
# [18]	train-auc:0.916436
# [19]	train-auc:0.922748
# [20]	train-auc:0.927580
# [21]	train-auc:0.928837
# [22]	train-auc:0.933250
# [23]	train-auc:0.937383
# [24]	train-auc:0.941908
# [25]	train-auc:0.945873
# [26]	train-auc:0.948862
# [27]	train-auc:0.950035
# [28]	train-auc:0.954615
# [29]	train-auc:0.958414
# [30]	train-auc:0.961318
# [31]	train-auc:0.965480
# [32]	train-auc:0.967435
# [33]	train-auc:0.970786
# [34]	train-auc:0.972741
# [35]	train-auc:0.975897
# [36]	train-auc:0.977042
# [37]	train-auc:0.978662
# [38]	train-auc:0.980059
# [39]	train-auc:0.981008
# [40]	train-auc:0.982796
# [41]	train-auc:0.984304
# [42]	train-auc:0.985952
# [43]	train-auc:0.986343
# [44]	train-auc:0.987851
# [45]	train-auc:0.988828
# [46]	train-auc:0.991063
# [47]	train-auc:0.992292
# [48]	train-auc:0.993129
# [49]	train-auc:0.993967
# [50]	train-auc:0.995084
# [51]	train-auc:0.995922
# [52]	train-auc:0.995783
# [53]	train-auc:0.995839
# Stopping. Best iteration:
# [51]	train-auc:0.995922
#    Feature     Gain       Cover      Frequency
# 1  edge_461765 0.06230002 0.02967519 0.03896104
# 2  edge_644724 0.05439136 0.05741448 0.03896104
# 3  edge_105991 0.04677896 0.03430730 0.04545455
# 4  edge_269013 0.04587242 0.02044381 0.01298701
# 5  edge_343620 0.03344086 0.02665531 0.01948052
# 6  edge_929556 0.03136588 0.00824210 0.01298701
# 7  edge_929738 0.03077041 0.02416811 0.01948052
# 8  edge_58549  0.02680440 0.02997280 0.03246753
# 9  edge_274493 0.02516942 0.01345901 0.01298701
# 10 edge_266939 0.02442158 0.03478634 0.03246753
#        ylab
#           0   1
#   FALSE 137   1
#   TRUE   18 230
# [1] 0.9507772

# %%
importanceRaw <- xgboost::xgb.importance(feature_names = colnames(xmat), model = mod, data = xmat, label = ylab)
# Cleaning for better display 
importanceClean <- importanceRaw[,`:=`(Cover=NULL, Frequency=NULL)]
head(importanceRaw)
head(importanceClean)
# Out:
# Warning message in xgboost::xgb.importance(feature_names = colnames(xmat), model = mod, :
# “xgb.importance: parameters 'data', 'label' and 'target' are deprecated”
#   Feature     Gain
# 1 edge_461765 0.06230002
# 2 edge_644724 0.05439136
# 3 edge_105991 0.04677896
# 4 edge_269013 0.04587242
# 5 edge_343620 0.03344086
# 6 edge_929556 0.03136588
#   Feature     Gain
# 1 edge_461765 0.06230002
# 2 edge_644724 0.05439136
# 3 edge_105991 0.04677896
# 4 edge_269013 0.04587242
# 5 edge_343620 0.03344086
# 6 edge_929556 0.03136588

# %%
imptab <- xgboost::xgb.importance(model = mod)
colnames(imptab)[1] <- 'EdgeID'

edges <- as.numeric( str_replace_all(imptab$EdgeID, 'edge_', '') )
imptab$EdgeID <- edges

top_edges <- dat %>% dplyr::filter(EdgeID %in% edges) %>% 
  dplyr::select(Study, EdgeID, LCell, Ligand, Receptor, RCell, S1, med_diff) %>% 
  dplyr::group_by(Study, EdgeID, LCell, Ligand, Receptor, RCell) %>% 
  dplyr::summarize(S1avg = mean(S1), med_diff_avg=mean(med_diff)) 


top_edges <- dplyr::inner_join(top_edges, imptab) 
top_edges <- top_edges %>% arrange(desc(Gain))
top_edges

#colnames(top_edges)[9] <- 'imp'
#top_edges %>% dplyr::arrange(desc(imp))
# Out:
# Joining, by = "EdgeID"
#    Study EdgeID  LCell                         Ligand   Receptor
# 1  STAD   461765 Keratinocytes                 CALM3    KCNQ1
# 2  STAD   644724 Mesangial cells               TGFB2    ACVR1
# 3  STAD   105991 CD4+ T-cells                  IL1B     IL1R2
# 4  STAD   269013 CLP                           ADAM28   ITGA4
# 5  STAD   343620 Epithelial cells              VCAN     TLR1
# 6  STAD   929556 Preadipocytes                 ADAM9    ITGA6
# 7  STAD   929738 Preadipocytes                 HSPG2    ITGA2
# 8  STAD    58549 b-cell                        CALM1    SELL
# 9  STAD   274493 CLP                           CD34     SELP
# 10 STAD   266939 Class-switched memory B-cells LAMA5    ITGA2
# 11 STAD   276510 CLP                           TFPI     SDC4
# 12 STAD   992734 Smooth muscle                 CFH      SELL
# 13 STAD   419017 Hepatocytes                   B2M      CD3G
# 14 STAD   363955 Erythrocytes                  B2M      TFRC
# 15 STAD   769233 Neutrophils                   PROC     PROCR
# 16 STAD   852917 pDC                           CALM3    KCNQ1
# 17 STAD   411068 Hepatocytes                   COL5A2   ITGB1
# 18 STAD   583906 Megakaryocytes                ADAM28   ITGA4
# 19 STAD   271039 CLP                           B2M      TFRC
# 20 STAD   769218 Neutrophils                   PF4      PROCR
# 21 STAD  1051860 Th2 cells                     CALM1    KCNQ1
# 22 STAD   485283 ly Endothelial cells          CELA3B   CHRM3
# 23 STAD   274754 CLP                           CD34     SELL
# 24 STAD   661096 Monocytes                     CALM1    PDE1A
# 25 STAD   344607 Epithelial cells              CALM3    KCNQ1
# 26 STAD   585598 Megakaryocytes                CALM2    PDE1A
# 27 STAD   929671 Preadipocytes                 EFNB1    EPHB2
# 28 STAD   271977 CLP                           ADAM28   ITGA4
# 29 STAD   586881 Megakaryocytes                CALM1    GRM3
# 30 STAD   773120 Neutrophils                   IL1B     IL1R2
# ⋮  ⋮     ⋮       ⋮                             ⋮        ⋮
# 49 STAD   422531 HSC                           ADAM28   ITGA4
# 50 STAD    89853 CD4+ memory T-cells           CALM1    PDE1C
# 51 STAD   769007 Neutrophils                   ADAM9    ITGA6
# 52 STAD   426271 HSC                           IL1B     IL1R1
# 53 STAD   360774 Erythrocytes                  CD34     SELP
# 54 STAD  1001028 Smooth muscle                 B2M      LILRB1
# 55 STAD   777028 Neutrophils                   MADCAM1  ITGA4
# 56 STAD   665014 Monocytes                     CD55     EMR2
# 57 STAD   411280 Hepatocytes                   THBS1    LRP1
# 58 STAD   426161 HSC                           B2M      LILRB1
# 59 STAD   269711 CLP                           ADAM28   ITGA4
# 60 STAD   424164 HSC                           ADAM28   ITGA4
# 61 STAD   273908 CLP                           TFPI     SDC4
# 62 STAD   273329 CLP                           ADAM28   ITGA4
# 63 STAD   773241 Neutrophils                   SERPINE1 PLAUR
# 64 STAD   994864 Smooth muscle                 UBA52    TGFBR2
# 65 STAD    87731 CD4+ memory T-cells           CALM1    SELL
# 66 STAD   366157 Erythrocytes                  CALM2    SELL
# 67 STAD    63900 b-cell                        CALM1    SELL
# 68 STAD   767591 Neutrophils                   PROC     PROCR
# 69 STAD   586892 Megakaryocytes                CALM2    MYLK
# 70 STAD   353464 Epithelial cells              CALM3    KCNQ1
# 71 STAD   427994 HSC                           ADAM9    ITGA6
# 72 STAD   368404 Erythrocytes                  IL8      CXCR2
# 73 STAD   400954 Hepatocytes                   THBS1    CD36
# 74 STAD   585277 Megakaryocytes                PF4      PROCR
# 75 STAD  1056008 Tregs                         B2M      CD3G
# 76 STAD   587663 Megakaryocytes                THBS1    LRP1
# 77 STAD   581621 Megakaryocytes                THBS1    CD36
# 78 STAD   664468 Monocytes                     HGF      CD44
#    RCell               S1avg      med_diff_avg Gain        Cover
# 1  Eosinophils         -0.1360663 -0.06727854  0.06230002  0.029675187
# 2  Erythrocytes         0.1491027  0.06098796  0.05439136  0.057414484
# 3  Megakaryocytes       0.1344380  0.08061782  0.04677896  0.034307300
# 4  CD4+ T-cells         0.1450928  0.07476685  0.04587242  0.020443815
# 5  CLP                  0.1338749  0.05075972  0.03344086  0.026655306
# 6  NKT                 -0.1377886 -0.06669210  0.03136588  0.008242100
# 7  NKT                 -0.1337764 -0.05932083  0.03077041  0.024168111
# 8  CD4+ memory T-cells  0.1437626  0.07280981  0.02680440  0.029972799
# 9  naive B-cells        0.1350765  0.05640268  0.02516942  0.013459010
# 10 Preadipocytes       -0.1341085 -0.05458281  0.02442158  0.034786339
# 11 Sebocytes            0.1449398  0.06148362  0.02344920  0.028744036
# 12 CD8+ Tcm             0.1524863  0.05731979  0.02219778  0.031859365
# 13 Tregs                0.1413066  0.08895515  0.02160343  0.016210656
# 14 HSC                  0.1348585  0.05791147  0.02141049  0.027538955
# 15 HSC                  0.1367843  0.05863951  0.02104436  0.015870569
# 16 NKT                 -0.1409183 -0.06609676  0.02006339  0.030585870
# 17 Megakaryocytes       0.1411448  0.08906000  0.01891798  0.003871802
# 18 CD8+ Tcm             0.1356267  0.08854221  0.01829748  0.018809746
# 19 Endothelial cells    0.1349508  0.05514692  0.01748698  0.035272648
# 20 HSC                  0.1398450  0.06276571  0.01694801  0.012784948
# 21 NKT                 -0.1384579 -0.07370868  0.01632077  0.008851648
# 22 Erythrocytes         0.1435813  0.05717231  0.01608917  0.023291533
# 23 Neutrophils          0.1357714  0.05174686  0.01592898  0.037195681
# 24 CLP                  0.1344942  0.05369619  0.01495062  0.036473590
# 25 Eosinophils         -0.1413075 -0.07762214  0.01468140  0.004378263
# 26 CLP                  0.1413992  0.07139341  0.01394873  0.017666059
# 27 NKT                 -0.1395406 -0.06032444  0.01371799  0.007558495
# 28 iDC                  0.1371315  0.06269328  0.01330137  0.007763750
# 29 Erythrocytes         0.1547719  0.07231569  0.01289732  0.016105155
# 30 Megakaryocytes       0.1352791  0.07801638  0.01285821  0.010726650
# ⋮  ⋮                   ⋮          ⋮            ⋮           ⋮
# 49 CLP                  0.1366547  0.05928596  0.005776529 0.0073798506
# 50 naive B-cells        0.1391819  0.07993533  0.005758573 0.0078288909
# 51 HSC                  0.1381288  0.06675942  0.005619340 0.0037985219
# 52 Megakaryocytes       0.1399667  0.06327210  0.005131725 0.0067942553
# 53 CD8+ Tcm             0.1343723  0.06796299  0.005085818 0.0028600843
# 54 Megakaryocytes       0.1420884  0.06622427  0.005077288 0.0004212300
# 55 Neutrophils          0.1360948  0.07739255  0.004990547 0.0037570632
# 56 Monocytes            0.1392053  0.06950839  0.004986637 0.0077132903
# 57 Megakaryocytes       0.1357678  0.08684014  0.004900084 0.0074724260
# 58 Megakaryocytes       0.1368443  0.07460259  0.004754200 0.0060383211
# 59 CD8+ Tcm             0.1451954  0.07516230  0.004685380 0.0046408792
# 60 HSC                  0.1376682  0.07416461  0.004585962 0.0058283534
# 61 Mesangial cells      0.1482658  0.06442650  0.004553046 0.0081262774
# 62 Megakaryocytes       0.1437194  0.07596437  0.004469480 0.0036206325
# 63 Megakaryocytes       0.1337772  0.06750381  0.004443155 0.0011986397
# 64 CLP                  0.1388292  0.05225960  0.004430218 0.0068291993
# 65 HSC                  0.1382777  0.06167346  0.004415990 0.0021854224
# 66 Megakaryocytes       0.1519259  0.07658822  0.004375734 0.0060430553
# 67 Megakaryocytes       0.1408972  0.08353880  0.003878376 0.0006544182
# 68 Epithelial cells     0.1394122  0.07222039  0.003807975 0.0015278563
# 69 Erythrocytes         0.1474431  0.07659388  0.003735233 0.0021919515
# 70 NKT                 -0.1337773 -0.07158658  0.003642513 0.0007075479
# 71 Neutrophils          0.1354267  0.06490238  0.003556920 0.0091993754
# 72 Neutrophils          0.1351055  0.06790349  0.003440554 0.0079459556
# 73 Adipocytes           0.1480999  0.06707206  0.002983424 0.0011195448
# 74 Chondrocytes         0.1369744  0.07814728  0.002777345 0.0065417341
# 75 CD8+ Tcm             0.1484447  0.08340847  0.002737251 0.0087242932
# 76 Hepatocytes          0.1341780  0.08118299  0.002696869 0.0085919715
# 77 Adipocytes           0.1393356  0.06388822  0.002271178 0.0079385144
# 78 Melanocytes          0.1363150  0.05449398  0.002036802 0.0080993758
#    Frequency
# 1  0.038961039
# 2  0.038961039
# 3  0.045454545
# 4  0.012987013
# 5  0.019480519
# 6  0.012987013
# 7  0.019480519
# 8  0.032467532
# 9  0.012987013
# 10 0.032467532
# 11 0.025974026
# 12 0.025974026
# 13 0.025974026
# 14 0.019480519
# 15 0.012987013
# 16 0.019480519
# 17 0.019480519
# 18 0.025974026
# 19 0.025974026
# 20 0.012987013
# 21 0.019480519
# 22 0.019480519
# 23 0.025974026
# 24 0.025974026
# 25 0.006493506
# 26 0.012987013
# 27 0.006493506
# 28 0.006493506
# 29 0.012987013
# 30 0.012987013
# ⋮  ⋮
# 49 0.006493506
# 50 0.012987013
# 51 0.006493506
# 52 0.006493506
# 53 0.006493506
# 54 0.006493506
# 55 0.006493506
# 56 0.006493506
# 57 0.006493506
# 58 0.006493506
# 59 0.006493506
# 60 0.006493506
# 61 0.006493506
# 62 0.006493506
# 63 0.006493506
# 64 0.006493506
# 65 0.006493506
# 66 0.006493506
# 67 0.006493506
# 68 0.006493506
# 69 0.006493506
# 70 0.006493506
# 71 0.006493506
# 72 0.006493506
# 73 0.006493506
# 74 0.006493506
# 75 0.006493506
# 76 0.006493506
# 77 0.006493506
# 78 0.006493506

# %%
dim(x)
dim(top_edges)
# Out:
# [1] 386 143
# [1] 78 11

# %%
qplot(x=med_diff_avg, y=S1avg, data=top_edges)
qplot(x=med_diff_avg, y=Gain, data=top_edges)
qplot(x=1:nrow(top_edges), y=Gain, data=top_edges)
# Out:
# plot without title
# plot without title
# plot without title

# %%
res0 <- unique(top_edges[,c('LCell','RCell','Gain')])
res0 <- res0 %>% group_by(LCell, RCell) %>% mutate(Gain=sum(Gain))
res1 <- matrix(data=as.matrix(res0[,c(1,2)]), ncol = 2, byrow = F)
g <- graph_from_data_frame(res1, directed = T)
g <- set_edge_attr(g, "weight", value = res0$Gain)

# %%
ggraph(g, layout='fabric', sort.by = node_rank_fabric()) +
  geom_node_range(colour = 'grey') +
  geom_edge_span(end_shape = 'square', edge_width=1.5, mapping = aes(colour=weight),  arrow = arrow(), end_cap = circle(0.1, 'cm')) + #end_cap = circle(1.0, 'cm'),
  scale_edge_colour_viridis() +
  theme_graph() +
  geom_node_label(aes(label = name), hjust = 0, nudge_x = -0)
# Out:
# plot without title

# %%
ggraph(g, layout='fabric', sort.by = node_rank_fabric()) +
  geom_node_range(colour = 'grey') +
  geom_edge_span(end_shape = 'square', edge_width=1.5, mapping = aes(colour=weight), arrow = arrow()) + #end_cap = circle(1.0, 'cm'), 
  scale_edge_colour_viridis() +
  theme_graph()
# Out:
# plot without title
