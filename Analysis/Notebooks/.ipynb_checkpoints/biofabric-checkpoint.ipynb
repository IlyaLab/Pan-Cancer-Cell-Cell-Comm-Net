# %%
install.packages('ggraph')
# Out:
# Installing package into ‘/home/dave/R/x86_64-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘tweenr’, ‘polyclip’, ‘RcppEigen’, ‘gridExtra’, ‘RcppArmadillo’, ‘ggforce’, ‘igraph’, ‘ggrepel’, ‘viridis’, ‘tidygraph’, ‘graphlayouts’

# %%
library(readr)
library(dplyr)
library(igraph)
library(ggraph)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# Error in library(igraph): there is no package called ‘igraph’
# Traceback:
#
# 1. library(igraph)

# %%
result_table <- read_tsv(file = 'resultsTables/paper_pfi_studies.tsv')
# Out:
# Parsed with column specification:
# cols(
#   Study = col_character(),
#   EdgeID = col_double(),
#   LCell = col_character(),
#   Ligand = col_character(),
#   Receptor = col_character(),
#   RCell = col_character(),
#   S1 = col_double(),
#   med_diff = col_double()
# )

# %%
head(result_table)
# Out:
#   Study EdgeID LCell               Ligand Receptor RCell             S1
# 1 STAD  271039 CLP                 B2M    TFRC     Endothelial cells 0.1349508
# 2 STAD   60750 b-cell              ADAM28 ITGA4    CLP               0.1376915
# 3 ESCA  656227 Mesangial cells     SPP1   CD44     Sebocytes         0.1836831
# 4 ESCA  658080 Mesangial cells     SPP1   CD44     Tregs             0.1837930
# 5 STAD   87731 CD4+ memory T-cells CALM1  SELL     HSC               0.1382777
# 6 STAD   63900 b-cell              CALM1  SELL     Megakaryocytes    0.1408972
#   med_diff
# 1 0.05514692
# 2 0.06623750
# 3 0.08224961
# 4 0.07973856
# 5 0.06167346
# 6 0.08353880

# %%
si <- 'STAD'
#si <- 'PAAD'
#si <- 'SKCM'
#si <- 'LUSC'

# %%
res0 <- result_table %>% dplyr::filter(Study == si)

# %%
res1 <- data.frame(from=res0$LCell, to=res0$RCell, ligand=res0$Ligand, receptor=res0$Receptor, S1=res0$S1, Med_diff=res0$med_diff, Study=res0$Study)

# %%
head(res1)
# Out:
#   from                to                  ligand receptor S1        Med_diff
# 1 CLP                 Endothelial cells   B2M    TFRC     0.1349508 0.05514692
# 2 b-cell              CLP                 ADAM28 ITGA4    0.1376915 0.06623750
# 3 CD4+ memory T-cells HSC                 CALM1  SELL     0.1382777 0.06167346
# 4 b-cell              Megakaryocytes      CALM1  SELL     0.1408972 0.08353880
# 5 CD4+ memory T-cells pDC                 CALM1  PTPRA    0.1342030 0.06611083
# 6 b-cell              CD4+ memory T-cells CALM1  SELL     0.1437626 0.07280981
#   Study
# 1 STAD
# 2 STAD
# 3 STAD
# 4 STAD
# 5 STAD
# 6 STAD

# %%
g <- graph_from_data_frame(res1, directed = T)

# %%
g <- set_edge_attr(g, "weight", value = abs(E(g)$S1))

# %%
g
# Out:
# IGRAPH 262661e DNW- 32 142 --
# + attr: name (v/c), ligand (e/c), receptor (e/c), S1 (e/n), Med_diff
# | (e/n), Study (e/c), weight (e/n)
# + edges from 262661e (vertex names):
#  [1] CLP                ->Endothelial cells
#  [2] b-cell             ->CLP
#  [3] CD4+ memory T-cells->HSC
#  [4] b-cell             ->Megakaryocytes
#  [5] CD4+ memory T-cells->pDC
#  [6] b-cell             ->CD4+ memory T-cells
#  [7] CD4+ T-cells       ->Megakaryocytes
# + ... omitted several edges

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggraph(g, layout='fabric', sort.by = node_rank_fabric()) +
  geom_node_range(colour = 'grey') +
  geom_edge_span(end_shape = 'square', edge_width=1.5, mapping = aes(colour=S1)) +
  scale_edge_colour_viridis() +
  theme_graph() +
  geom_node_label(aes( label = name), hjust = 0, nudge_x = -10)

#ggsave('skcm_net.png', width=15, height=8)
# Out:
# plot without title

# %%
g
# Out:
# IGRAPH 12ccdd5 DN-- 32 142 --
# + attr: name (v/c), ligand (e/c), receptor (e/c), S1 (e/n), Med_diff
# | (e/n), Study (e/c)
# + edges from 12ccdd5 (vertex names):
#  [1] CLP                ->Endothelial cells
#  [2] b-cell             ->CLP
#  [3] CD4+ memory T-cells->HSC
#  [4] b-cell             ->Megakaryocytes
#  [5] CD4+ memory T-cells->pDC
#  [6] b-cell             ->CD4+ memory T-cells
#  [7] CD4+ T-cells       ->Megakaryocytes
# + ... omitted several edges

# %%
indegree  <- igraph::degree(g, mode = 'in')
outdegree <- igraph::degree(g, mode = 'out')
all(names(indegree) == names(outdegree))
data.frame(indegree, outdegree, indegree+outdegree)
# Out:
# [1] TRUE
#                               indegree outdegree indegree...outdegree
# CLP                           13       13        26
# b-cell                         0        4         4
# CD4+ memory T-cells            4        7        11
# CD4+ T-cells                   2        3         5
# Mesangial cells                1        2         3
# HSC                           11       10        21
# NKT                           10        1        11
# pDC                            3        5         8
# Tregs                          2        1         3
# CD8+ Tcm                      10        4        14
# Monocytes                      5        8        13
# Sebocytes                      1        1         2
# Th2 cells                      6        1         7
# Hepatocytes                    2        6         8
# Neutrophils                   13       18        31
# Chondrocytes                   1        4         5
# Erythrocytes                  12       11        23
# Keratinocytes                  0        2         2
# Preadipocytes                  1        5         6
# Smooth muscle                  2        6         8
# Megakaryocytes                25       25        50
# Epithelial cells               2        3         5
# ly Endothelial cells           0        1         1
# Class-switched memory B-cells  0        1         1
# Endothelial cells              1        0         1
# naive B-cells                  4        0         4
# iDC                            1        0         1
# Melanocytes                    2        0         2
# Adipocytes                     2        0         2
# Eosinophils                    3        0         3
# aDC                            1        0         1
# Macrophages M1                 2        0         2

# %%
igraph::articulation_points(g)
# Out:
# + 4/32 vertices, named, from 12ccdd5:
# [1] Preadipocytes  Erythrocytes   Megakaryocytes CLP

# %%
clus1 <- igraph::cluster_label_prop(g)
clusdf1 <- data.frame(clus1$names, clus1$membership)

# %%
clus2 <- igraph::cluster_infomap(g)
clusdf2 <- data.frame(clus2$names, clus2$membership)

# %%
clusRes <- dplyr::inner_join(clusdf1, clusdf2, by=c('clus1.names' = 'clus2.names'))
clusRes
# Out:
#    clus1.names                   clus1.membership clus2.membership
# 1  CLP                           1                2
# 2  b-cell                        2                1
# 3  CD4+ memory T-cells           1                4
# 4  CD4+ T-cells                  1                1
# 5  Mesangial cells               1                1
# 6  HSC                           1                2
# 7  NKT                           3                1
# 8  pDC                           1                4
# 9  Tregs                         1                4
# 10 CD8+ Tcm                      1                3
# 11 Monocytes                     4                1
# 12 Sebocytes                     1                3
# 13 Th2 cells                     1                1
# 14 Hepatocytes                   1                1
# 15 Neutrophils                   1                2
# 16 Chondrocytes                  1                1
# 17 Erythrocytes                  1                3
# 18 Keratinocytes                 5                2
# 19 Preadipocytes                 3                1
# 20 Smooth muscle                 1                1
# 21 Megakaryocytes                1                1
# 22 Epithelial cells              1                1
# 23 ly Endothelial cells          6                3
# 24 Class-switched memory B-cells 3                1
# 25 Endothelial cells             1                1
# 26 naive B-cells                 1                1
# 27 iDC                           1                1
# 28 Melanocytes                   4                1
# 29 Adipocytes                    1                1
# 30 Eosinophils                   1                2
# 31 aDC                           1                1
# 32 Macrophages M1                1                1

# %%
plot(clus1, y=g)
# Out:
# Plot with title “”

# %%
plot(clus2, y=g)
# Out:
# Plot with title “”

# %%
igraph::compare(clus1, clus2, method='nmi')
# Out:
# [1] 0.2571559

# %%
 V(g)[1]
# Out:
# + 1/32 vertex, named, from 0cf9258:
# [1] CLP

# %%
mstg <- (igraph::minimum.spanning.tree(g, weights = (1.0/E(g)$weight) ))

# %%
ggraph(mstg, layout='fabric', sort.by = node_rank_fabric()) +
  geom_node_range(colour = 'grey') +
  geom_edge_span(end_shape = 'square', edge_width=1.5, mapping = aes(colour=S1), end_cap = circle(0.5, 'cm'), arrow = arrow()) +
  scale_edge_colour_viridis() +
  theme_graph() +
  geom_node_label(aes(label = name), hjust = 0, nudge_x = -1)
# Out:
# plot without title

# %%
eigg <- igraph::eigen_centrality(g, directed = T)
sort(eigg$vector)
# Out:
# Warning message in igraph::eigen_centrality(g, directed = T):
# “At centrality.c:362 :Weighted directed graph in eigenvector centrality”
#                        b-cell                 Keratinocytes
#                  0.000000e+00                  0.000000e+00
#          ly Endothelial cells Class-switched memory B-cells
#                  0.000000e+00                  0.000000e+00
#                 Preadipocytes                   Melanocytes
#                  4.121798e-18                  1.341243e-02
#                     Monocytes             Endothelial cells
#                  5.565117e-02                  6.088793e-02
#                           iDC                     Sebocytes
#                  6.187184e-02                  6.539483e-02
#               Mesangial cells                 naive B-cells
#                  6.689547e-02                  7.377435e-02
#                           NKT                  Chondrocytes
#                  8.025440e-02                  8.959355e-02
#                   Hepatocytes                  CD4+ T-cells
#                  9.560477e-02                  9.904013e-02
#                    Adipocytes                         Tregs
#                  1.003993e-01                  1.073125e-01
#                           pDC                           aDC
#                  1.209583e-01                  1.313057e-01
#                   Eosinophils              Epithelial cells
#                  1.336754e-01                  1.390785e-01
#           CD4+ memory T-cells                 Smooth muscle
#                  1.409278e-01                  1.580272e-01
#                Macrophages M1                      CD8+ Tcm
#                  2.457906e-01                  3.226379e-01
#                     Th2 cells                  Erythrocytes
#                  4.750869e-01                  5.491442e-01
#                           HSC                           CLP
#                  6.239450e-01                  6.897922e-01
#                   Neutrophils                Megakaryocytes
#                  8.367334e-01                  1.000000e+00
